# %%
import numpy as np
import pandas as pd 
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import os
import cv2
import pickle
import random
from sklearn.svm import SVC

# %%
images_directory = 'D:\\Data\\work\\data'

# %%
categories = ['Closed_Eyes','Open_Eyes']

# %%
data=[]

# %%
for category in categories:
    path = os.path.join(images_directory,category)
    label = categories.index(category)
    
    for img in os.listdir(path):
        imgpath = os.path.join(path,img)
        train_data = cv2.imread(imgpath,0)
        train_data = cv2.resize(train_data,(80,80))
        image = np.array(train_data).flatten()
        data.append([image,label])

# %%
pickle_in = open('transformed.pickle','wb')
pickle.dump(data,pickle_in)
pickle_in.close()

# %%
pickle_in = open('D:\\Data\\work\\transformed.pickle','rb')
data = pickle.load(pickle_in)
pickle_in.close()

# %%
random.shuffle(data)
features = []
labels = []

# %%
for feature, label in data:
    features.append(feature)
    labels.append(label)

# %%
train_x, test_x, train_y,test_y = train_test_split(features,labels, test_size= 0.1)

# %%
model = SVC(C=1, kernel= 'poly', gamma= 'auto')

# %%
train_model = model.fit(train_x,train_y)

# %%
print(train_model)
# Out:
# SVC(C=1, gamma='auto', kernel='poly')

# %%
prediction = train_model.predict(test_x)

# %%
accuracy = train_model.score(test_x,test_y)

# %%
print(test_x[0])
# Out:
# [118 118 111 ...  84  87  84]

# %%
print('Predictions is: ',categories[prediction[3]])
# Out:
# Predictions is:  Open_Eyes

# %%
eye_state = test_x[3].reshape(80,80)
plt.imshow(eye_state, cmap= 'gray')
plt.show()

# %%
pickle_in = open('model_2.xml','wb')
pickle.dump(train_model,pickle_in)
pickle_in.close()

# %%
pickle_in = open('D:\\Data\\work\\model.sav','rb')
loaded_model = pickle.load(pickle_in)
pickle_in.close()

# %%
loaded_model.predict((test_x[3]).reshape(1,-1))
# Out:
# array([1])

# %%
print(test_x[3].shape)
# Out:
# (6400,)

# %%
print(test_x[3].size)
# Out:
# 6400

# %%
print(test_x[3].ndim)
# Out:
# 1
